# %% [markdown]
# # Reading change_requests.db into Pandas DataFrames
# This notebook connects to the `change_requests.db` SQLite database, explores its tables, and loads them into Pandas DataFrames.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('change_requests.db')
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:")
for table in tables:
    print(table[0])
# Out:
# Tables in the database:
# change_requests
# sqlite_sequence

# %%
dataframes = {}

for table in tables:
    table_name = table[0]
    print(f"\nLoading table: {table_name}")
    
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    dataframes[table_name] = df
    
    print(f"Preview of {table_name}:")
    display(df)
# Out:
# Loading table: change_requests
# Preview of change_requests:
#     id                   project_name change_number          requested_by  \
# 0    1              Martinez-Anderson        CR-905           Spencer Ray
# 1    2                     Massey Inc        CR-335            David Wang
# 2    3                      Lewis Ltd        CR-303          Alicia Lopez
# 3    4                Morris-Figueroa        CR-382     Christine Ramirez
# 4    5       Miller, Gibson and Bryan        CR-750        Willie Johnson
# 5    6     Simpson, Coleman and Davis        CR-375            Paul Burns
# 6    7     Walker, Thompson and Reese        CR-782            Andrea Lin
# 7    8          Smith, Lang and Dixon        CR-446          Sydney Leach
# 8    9      Smith, Ramirez and Ingram        CR-473         Jeffrey Brown
# 9   10                Benton and Sons        CR-313       Elizabeth Lopez
# 10  11                  Roberts-Cantu        CR-780         Dylan Johnson
# 11  12    Brewer, Jefferson and Rivas        CR-229         Brenda Morris
# 12  13      Sloan, Love and Hendricks        CR-172      Patrick Phillips
# 13  14         White, Huber and Young        CR-503            Sarah Soto
# 14  15                      Lewis Ltd        CR-386            Jason Long
# 15  16                      Reyes-Lee        CR-870         Kayla Nichols
# 16  17                     Mata Group        CR-212             Erin Hill
# 17  18                     Arnold LLC        CR-764       Michael Mccarty
# 18  19                 Stewart-Miller        CR-557       Xavier Andersen
# 19  20                   Guerra-White        CR-393        Michael Moreno
# 20  21                    Lewis-Perez         CR-22             Jake Rich
# 21  22                    Short Group        CR-480     Michael Schneider
# 22  23                    Avery Group        CR-310      Dr. Jon Anderson
# 23  24                      Perez Inc        CR-916          Michael Reed
# 24  25                 Olsen-Campbell        CR-138       Danielle Norman
# 25  26               Robertson-Torres        CR-614    Christopher Archer
# 26  27                   Butler-Smith        CR-213         Robert Powers
# 27  28                 Davis and Sons        CR-921         Robert Reeves
# 28  29                     Patton Ltd        CR-946      Anthony Robinson
# 29  30                    Morse-Perez        CR-281    Christopher Bailey
# 30  31                      Smith PLC        CR-940       Elizabeth Kelly
# 31  32                  Hanson-Dawson        CR-568           Mary Harris
# 32  33     Watson, Garner and Holland        CR-978  Ms. Christine Romero
# 33  34                  Williams-Park        CR-653         Joe Patterson
# 34  35                   Madden Group        CR-660         Stacey Morris
# 35  36                    Manning-Cox         CR-73         Andrew Powers
# 36  37             Washington-Gilmore        CR-117             Paul Lane
# 37  38      Phelps, Webb and Stephens        CR-100       Michael Mendoza
# 38  39                  Hicks-Wallace        CR-549           Duane Brown
# 39  40  Richardson, Coleman and Scott        CR-906         Michael Baker
# 40  41                      Bryan LLC        CR-692          Keith Foster
# 41  42       Osborne, Miller and Cruz        CR-325        Christy Rivera
# 42  43               Powers-Gutierrez        CR-166      Mr. Dakota White
# 43  44        Bass, Bennett and Stone        CR-511       Jennifer Harris
# 44  45                   Oconnell Ltd        CR-754   Nicole Melendez DVM
# 45  46          Ford, French and Chan        CR-448     Mario Fitzpatrick
# 46  47                       Hill Ltd        CR-165       Dustin Thompson
# 47  48              Morrison-Mitchell        CR-146          Brian Bailey
# 48  49                   Clark-Morgan        CR-519           Sarah Downs
# 49  50                Robinson-Howell        CR-549        Gregory Garcia
#
#    date_of_request          presented_to  \
# 0       2025-03-27         Richard Avila
# 1       2025-04-06       Alyssa Peterson
# 2       2025-02-16     Kenneth Stokes MD
# 3       2025-03-16     Douglas Hernandez
# 4       2025-03-21   Christopher Charles
# 5       2025-01-04   Christopher Spencer
# 6       2025-02-22          Laura Holden
# 7       2025-01-17          Kathryn Hays
# 8       2025-01-12        Marissa Benson
# 9       2025-02-25          Bryan Mosley
# 10      2025-03-22         Joseph Taylor
# 11      2025-03-18        Mr. Gary Brown
# 12      2025-03-21         Reginald Ward
# 13      2025-03-16          Glen Schultz
# 14      2025-01-04           Sara Bryant
# 15      2025-02-20      Christian Morris
# 16      2025-03-14        Brittany Olson
# 17      2025-03-01           Mark Hughes
# 18      2025-04-06        Jennifer Allen
# 19      2025-01-31          Joshua Young
# 20      2025-03-02       John Cooley DDS
# 21      2025-03-22         Rebecca Clark
# 22      2025-01-06           David Weber
# 23      2025-04-01          Melanie Wood
# 24      2025-03-12     Alexandra Dickson
# 25      2025-01-25        Cynthia Flores
# 26      2025-03-05       Gregory Jenkins
# 27      2025-04-08           Amber Green
# 28      2025-01-25         Erin Valencia
# 29      2025-03-14      Whitney Gonzalez
# 30      2025-04-02         Barbara Morse
# 31      2025-01-15             Mark Hill
# 32      2025-02-08          Walter Mills
# 33      2025-02-10         Terry Perkins
# 34      2025-03-13        Benjamin Wyatt
# 35      2025-01-10       Jacqueline Rich
# 36      2025-01-10       Colton Williams
# 37      2025-02-05       Ashley Galloway
# 38      2025-01-27          Rachel Jones
# 39      2025-02-20      Victoria Edwards
# 40      2025-02-20          Ashley Cohen
# 41      2025-01-27        Haley Thompson
# 42      2025-03-15        Linda Franklin
# 43      2025-01-02      Samuel Hayes DVM
# 44      2025-03-01           David Allen
# 45      2025-03-02       Michael Roberts
# 46      2025-03-31  Christina Richardson
# 47      2025-01-04           Joel Medina
# 48      2025-03-05          Sydney Brown
# 49      2025-03-21      Dominique Bailey
#
#                                           change_name  \
# 0      Upgradable empowering Graphical User Interface
# 1                    Total zero-defect knowledge user
# 2                 Ergonomic fresh-thinking monitoring
# 3                      Monitored uniform architecture
# 4                     Persistent logistical help-desk
# 5               Synergized didactic pricing structure
# 6                       Assimilated national intranet
# 7                  Open-source executive installation
# 8                      Innovative intangible encoding
# 9                 Customizable fresh-thinking project
# 10             Customer-focused grid-enabled database
# 11    Networked demand-driven artificial intelligence
# 12                  Advanced disintermediate matrices
# 13  Grass-roots zero administration Local Area Net...
# 14       Vision-oriented zero tolerance collaboration
# 15                  Phased user-facing data-warehouse
# 16                           Total didactic challenge
# 17                     Upgradable reciprocal encoding
# 18               Horizontal context-sensitive synergy
# 19             Function-based clear-thinking software
# 20                  Programmable responsive algorithm
# 21                     Reduced responsive contingency
# 22               Assimilated analyzing knowledge user
# 23                  Up-sized 3rdgeneration definition
# 24                Open-architected bifurcated website
# 25                        Automated optimal emulation
# 26                   Centralized zero tolerance frame
# 27            Business-focused clear-thinking ability
# 28                     Front-line full-range approach
# 29             Team-oriented disintermediate approach
# 30                  Grass-roots empowering throughput
# 31             Function-based leadingedge flexibility
# 32        Organized next generation pricing structure
# 33             Universal bandwidth-monitored capacity
# 34                  Multi-tiered 6thgeneration matrix
# 35           Business-focused regional infrastructure
# 36                Organized system-worthy methodology
# 37                      Assimilated regional intranet
# 38                            Balanced radical portal
# 39                          Devolved optimal attitude
# 40        Synergistic client-driven Internet solution
# 41                       Mandatory radical monitoring
# 42                    Synchronized tangible structure
# 43             User-centric intangible superstructure
# 44                     Robust fault-tolerant paradigm
# 45   Stand-alone solution-oriented Local Area Network
# 46   Open-architected uniform artificial intelligence
# 47                        Focused client-driven model
# 48          Cloned bandwidth-monitored superstructure
# 49             Persevering value-added superstructure
#
#                                           description  \
# 0   Bank staff quality do science knowledge. Popul...
# 1   Election however enjoy view. Travel need somet...
# 2   Woman do either ago bed close. Under now conti...
# 3   Evening test need analysis. Attack start natio...
# 4   Detail term performance quickly maybe cold yea...
# 5   Total measure evidence her ask offer. Include ...
# 6   Generation data song others medical. Create wi...
# 7   Could around smile beat. Response large knowle...
# 8   Difficult brother hold born service. Far than ...
# 9   Join plan throw few cut. Very avoid letter you...
# 10  Smile research expert for candidate wife newsp...
# 11  Cause draw too during film together site. From...
# 12  Stuff successful administration court. Lose mo...
# 13  Kitchen effort strong paper visit. Court today...
# 14  Media writer standard data drive other herself...
# 15    High life read near store. Little station also.
# 16  Age visit cause. Look sister yard hair nor foo...
# 17  During such see carry music three million. Sig...
# 18  Wind within no force space. Physical clearly e...
# 19  Statement late trip across. Field record acros...
# 20  Pm theory wife move especially better range mi...
# 21  According degree stop respond program none. Ar...
# 22  Detail arrive seat technology police camera bu...
# 23  Fact grow wall everything or. Entire dream phy...
# 24  Production evening opportunity case represent....
# 25  Off same sit accept reason security sell. Surf...
# 26  Democratic those local ball impact election st...
# 27                 Fast item least admit choose poor.
# 28  Position value dog sound film college sign. Th...
# 29   Unit base than paper. Adult sing toward ability.
# 30  Whatever hundred political analysis others rat...
# 31  Part scientist future firm safe relate. High b...
# 32  Debate people risk someone a move. Heavy accor...
# 33                 Recent perhaps result boy purpose.
# 34  Article nor watch coach. Then break despite li...
# 35  Need war daughter safe design along condition....
# 36  Cut particular attorney street. Hot unit inter...
# 37  Seat any summer stay happen place. Change trut...
# 38  Discussion thought hour feeling picture not go...
# 39                Glass under represent professional.
# 40  Training want program next for. Again guess ey...
# 41  Many paper fill study look. Begin citizen mate...
# 42  People pretty now try friend. Herself must chu...
# 43  Stop other others subject. Though send anythin...
# 44  Hand guess measure. Score bring society. Resea...
# 45  Knowledge for ability few. Nearly agree player...
# 46  Idea hour although finally million certainly. ...
# 47  Though hotel beyond daughter television cultur...
# 48  Already among build structure write create let...
# 49  Relate choice drug list top. Seven particularl...
#
#                                                reason  \
# 0     Certainly wide ask police wind argue operation.
# 1         History yourself east career street become.
# 2           My early father system drug its response.
# 3             Meet common happy myself ago agreement.
# 4                             Side language hold lot.
# 5            Determine sometimes remember back large.
# 6                Father country help fight before my.
# 7   Record news forget something new model important.
# 8     Glass exist exactly society Mrs according over.
# 9                  Worker prove specific hope expert.
# 10  Operation determine explain great laugh report...
# 11     Than agency some discussion land best city Mr.
# 12                       Ability still painting tell.
# 13              Conference sometimes world when what.
# 14    Worry benefit also attack center score without.
# 15        Positive catch long politics look everyone.
# 16                 Television these subject pressure.
# 17                           Main site three involve.
# 18                   Politics kitchen claim security.
# 19                                 Agency serve deal.
# 20                   Tree total never see paper fire.
# 21           What any game responsibility adult tend.
# 22  Arrive hotel same ability tough enough law court.
# 23               Lead side compare which nature true.
# 24     During never far Mr everybody positive matter.
# 25                            Food sell attorney boy.
# 26                   Total remember cold miss middle.
# 27             Certain myself human forward standard.
# 28     Girl party authority various explain consumer.
# 29                        Increase figure very check.
# 30                     Move control citizen magazine.
# 31                              Report walk hospital.
# 32                                  Easy myself deal.
# 33  Television degree provide current between PM p...
# 34                       Wide president various push.
# 35  Short energy but experience control include en...
# 36          Peace mean phone country long management.
# 37  Policy hope local understand treat organizatio...
# 38      Everybody religious subject drop least cause.
# 39               Law more agency get since hold team.
# 40                       Prove less father her break.
# 41          Idea sure pick account investment appear.
# 42                Present hundred present help since.
# 43            Recently follow few reduce would major.
# 44            So before child local degree also yeah.
# 45             Develop drug people serious dream art.
# 46             Attack ability ready begin fire total.
# 47                  Newspaper bring likely figure no.
# 48     Several less garden career who sort establish.
# 49                         Tax act argue price board.
#
#                                            cost_items   category  \
# 0                    [{"item": "agree", "cost": 920}]      other
# 1   [{"item": "me", "cost": 306}, {"item": "report...      other
# 2                      [{"item": "loss", "cost": 19}]      other
# 3   [{"item": "effort", "cost": 261}, {"item": "fi...   software
# 4                   [{"item": "system", "cost": 124}]   hardware
# 5   [{"item": "relate", "cost": 396}, {"item": "fl...      other
# 6                    [{"item": "dream", "cost": 529}]   software
# 7   [{"item": "listen", "cost": 495}, {"item": "ag...   software
# 8                    [{"item": "those", "cost": 806}]      other
# 9   [{"item": "wife", "cost": 122}, {"item": "disc...   hardware
# 10  [{"item": "line", "cost": 653}, {"item": "food...   software
# 11  [{"item": "throughout", "cost": 420}, {"item":...   hardware
# 12  [{"item": "about", "cost": 439}, {"item": "bot...  personnel
# 13  [{"item": "size", "cost": 225}, {"item": "deep...   software
# 14                      [{"item": "for", "cost": 50}]   hardware
# 15  [{"item": "affect", "cost": 100}, {"item": "ap...      other
# 16  [{"item": "scientist", "cost": 406}, {"item": ...      other
# 17  [{"item": "although", "cost": 325}, {"item": "...      other
# 18                   [{"item": "early", "cost": 797}]   software
# 19                  [{"item": "strong", "cost": 516}]  personnel
# 20  [{"item": "since", "cost": 399}, {"item": "too...      other
# 21  [{"item": "still", "cost": 489}, {"item": "exe...  personnel
# 22  [{"item": "situation", "cost": 559}, {"item": ...   hardware
# 23  [{"item": "walk", "cost": 133}, {"item": "good...      other
# 24                [{"item": "official", "cost": 467}]      other
# 25  [{"item": "rock", "cost": 464}, {"item": "whit...   software
# 26  [{"item": "tend", "cost": 486}, {"item": "reac...   hardware
# 27  [{"item": "sometimes", "cost": 562}, {"item": ...      other
# 28  [{"item": "lawyer", "cost": 495}, {"item": "ba...      other
# 29  [{"item": "director", "cost": 687}, {"item": "...   hardware
# 30  [{"item": "sit", "cost": 28}, {"item": "bag", ...  personnel
# 31  [{"item": "picture", "cost": 841}, {"item": "e...   software
# 32  [{"item": "suffer", "cost": 747}, {"item": "po...      other
# 33  [{"item": "long", "cost": 374}, {"item": "Mr",...   software
# 34                   [{"item": "force", "cost": 154}]      other
# 35                   [{"item": "treat", "cost": 861}]  personnel
# 36  [{"item": "political", "cost": 218}, {"item": ...   software
# 37                      [{"item": "on", "cost": 913}]   hardware
# 38  [{"item": "wife", "cost": 320}, {"item": "prac...   software
# 39  [{"item": "player", "cost": 819}, {"item": "au...      other
# 40  [{"item": "TV", "cost": 251}, {"item": "animal...  personnel
# 41  [{"item": "begin", "cost": 856}, {"item": "poo...   software
# 42  [{"item": "investment", "cost": 241}, {"item":...      other
# 43  [{"item": "almost", "cost": 53}, {"item": "thi...   hardware
# 44  [{"item": "bag", "cost": 773}, {"item": "comme...   software
# 45  [{"item": "my", "cost": 400}, {"item": "couple...   hardware
# 46                    [{"item": "visit", "cost": 78}]      other
# 47                     [{"item": "local", "cost": 9}]   hardware
# 48  [{"item": "eat", "cost": 512}, {"item": "admin...      other
# 49  [{"item": "game", "cost": 527}, {"item": "inve...  personnel
#
#               timestamp
# 0   2025-02-05 03:24:23
# 1   2025-04-03 20:36:22
# 2   2025-03-05 07:39:24
# 3   2025-02-03 17:12:58
# 4   2025-03-15 05:24:54
# 5   2025-01-30 11:56:08
# 6   2025-03-30 14:51:57
# 7   2025-01-07 22:34:22
# 8   2025-03-27 23:01:57
# 9   2025-04-05 03:22:21
# 10  2025-03-13 00:31:11
# 11  2025-04-06 21:55:53
# 12  2025-03-30 05:51:56
# 13  2025-01-01 03:00:32
# 14  2025-01-24 15:15:47
# 15  2025-02-02 01:16:29
# 16  2025-02-06 22:57:45
# 17  2025-03-08 10:04:58
# 18  2025-04-09 22:52:39
# 19  2025-03-29 15:40:33
# 20  2025-03-23 17:47:51
# 21  2025-03-29 16:53:54
# 22  2025-03-14 06:58:42
# 23  2025-04-10 09:24:02
# 24  2025-02-25 01:47:59
# 25  2025-04-02 13:52:30
# 26  2025-02-08 05:13:31
# 27  2025-04-02 03:34:56
# 28  2025-02-18 13:49:49
# 29  2025-04-09 12:58:25
# 30  2025-03-31 06:47:01
# 31  2025-03-27 02:09:55
# 32  2025-01-14 15:27:51
# 33  2025-01-22 05:10:27
# 34  2025-02-18 23:10:05
# 35  2025-03-30 12:49:49
# 36  2025-04-09 00:00:37
# 37  2025-01-01 00:29:04
# 38  2025-02-24 18:06:33
# 39  2025-01-16 19:28:16
# 40  2025-01-10 20:14:25
# 41  2025-01-28 14:49:57
# 42  2025-03-31 05:45:24
# 43  2025-03-16 18:46:08
# 44  2025-03-02 12:45:56
# 45  2025-01-16 19:01:47
# 46  2025-03-08 23:42:26
# 47  2025-01-16 08:27:53
# 48  2025-02-19 10:10:13
# 49  2025-03-17 07:42:19
# Loading table: sqlite_sequence
# Preview of sqlite_sequence:
#               name  seq
# 0  change_requests   50

# %%
if 'change_requests' in dataframes:
    df_example = dataframes['change_requests']
    display(df_example.describe())
else:
    print("Replace 'your_table_name' with a valid table name from the list above.")
# Out:
#              id
# count  50.00000
# mean   25.50000
# std    14.57738
# min     1.00000
# 25%    13.25000
# 50%    25.50000
# 75%    37.75000
# max    50.00000

# %%
conn.close()
print("Database connection closed.")
# Out:
# Database connection closed.

# %% [markdown]
# ## Notes
# - Ensure `change_requests.db` is in the same directory as this notebook, or update the file path in the `sqlite3.connect()` call.
# - The `dataframes` dictionary stores all tables as Pandas DataFrames, accessible by table name.
# - Use `display()` for nicer output in Jupyter; it’s better than `print()` for DataFrames.
